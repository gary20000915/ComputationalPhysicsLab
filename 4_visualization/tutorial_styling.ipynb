# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ## Data Visualization using Matplotlib
#
# A simplest example:

# %%
plt.figure(1)
plt.plot([0,1,2],[3,6,8],'-',label="line 1")
plt.xlabel("X [unit]")
plt.ylabel(r"math $\pi$ [unit]")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Make it better

# %%
plt.figure(1)

plt.plot([0,1,2],[3,6,8],'-o',label="line 1",linewidth=3)
plt.xlabel("X [unit]",fontsize=16)
plt.ylabel(r"math $\pi$ [unit]",fontsize=16)
plt.legend(loc="best",frameon=False)
plt.show()

# %% [markdown]
# ### Tips 1: Use `rcParams` to change the style

# %%
plt.rcParams["font.family"] = "Poppins"
plt.rcParams["figure.figsize"] = 12, 8
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False
plt.rcParams["font.size"] = 22
plt.rcParams["figure.titlesize"] = "xx-large"
plt.rcParams["xtick.labelsize"] = "medium"
plt.rcParams["ytick.labelsize"] = "medium"

# %%
plt.figure(1)
plt.plot([0,1,2],[3,6,8],'-o',label="line 1",linewidth=4)
plt.plot([0,1,2],[4,3,9],'-o',label="line 2",linewidth=4)
plt.plot([0,1,2,3],[2,7,10,8],'-o',label="line 3",linewidth=4)
plt.xlabel("X [unit]")
plt.ylabel(r"math $\pi$ [unit]")
plt.legend(loc="best",frameon=False,fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family ['Poppins'] not found. Falling back to DejaVu Sans.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.

# %% [markdown]
# ### Tips 2: custmize your only color palettes
#
# REF:
# * https://www.pinterest.com/pin/449585975301363405/
# * https://coolors.co/

# %%
# color
tot = 255.0; colors = {}
colors["b"] = (114./tot, 158./tot, 206./tot)
colors["o"] = (255./tot, 158./tot, 74./tot)
colors["g"]  = (103./tot, 191./tot, 92./tot)
colors["m"]   = (173./tot, 139./tot, 201./tot)
colors["r"] = (237./tot, 102./tot, 93./tot)

# %%
plt.figure(1)
plt.plot([0,1,2],[3,6,8],'-o',color=colors["b"],label="line 1",linewidth=4)
plt.plot([0,1,2],[4,3,9],'-o',color=colors["o"],label="line 2",linewidth=4)
plt.plot([0,1,2,3],[2,7,10,8],'-o',color=colors["g"],label="line 3",linewidth=4)
plt.xlabel("X [unit]")
plt.ylabel(r"math $\pi$ [unit]")
plt.legend(loc="best",frameon=False,fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.
# findfont: Font family 'Poppins' not found.

# %% [markdown]
# ### Tips 3: Use other styles
#
# For example `SciencePlots` \
# ref: https://github.com/garrettj403/SciencePlots \
# install the SciencePlots by `pip install SciencePlots`
#
# Wiki: https://github.com/garrettj403/SciencePlots/wiki/Gallery

# %%
import matplotlib.pyplot as plt
plt.style.use(['science','notebook'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/site-packages/matplotlib/style/core.py:155, in use(style)
#     154 try:
# --> 155     rc = rc_params_from_file(style, use_default_template=False)
#     156     _apply_style(rc)
#
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/site-packages/matplotlib/__init__.py:862, in rc_params_from_file(fname, fail_on_error, use_default_template)
#     848 """
#     849 Construct a `RcParams` from file *fname*.
#     850
#    (...)
#     860     parameters specified in the file. (Useful for updating dicts.)
#     861 """
# --> 862 config_from_file = _rc_params_in_file(fname, fail_on_error=fail_on_error)
#     864 if not use_default_template:
#
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/site-packages/matplotlib/__init__.py:789, in _rc_params_in_file(fname, transform, fail_on_error)
#     788 rc_temp = {}
# --> 789 with _open_file_or_url(fname) as fd:
#     790     try:
#
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/site-packages/matplotlib/__init__.py:766, in _open_file_or_url(fname)
#     765 fname = os.path.expanduser(fname)
# --> 766 with open(fname, encoding='utf-8') as f:
#     767     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'science'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In [8], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.style.use(['science','notebook'])
#
# File /opt/homebrew/anaconda3/envs/comphyslab/lib/python3.9/site-packages/matplotlib/style/core.py:158, in use(style)
#     156     _apply_style(rc)
#     157 except IOError as err:
# --> 158     raise IOError(
#     159         "{!r} not found in the style library and input is not a "
#     160         "valid URL or path; see `style.available` for list of "
#     161         "available styles".format(style)) from err
#
# OSError: 'science' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
plt.figure(1)
plt.plot([0,1,2],[3,6,8],'-o',label="line 1")
plt.plot([0,1,2],[4,3,9],'-o',label="line 2")
plt.plot([0,1,2,3],[2,7,10,8],'-o',label="line 3")
plt.xlabel("X (unit)")
plt.ylabel(r"math $\pi$ (unit)")
plt.legend(loc="best",frameon=False)
plt.tight_layout()
plt.savefig('fig_sciplots.pdf')

# %% [markdown]
# ### Seaborn
#
# Another popular package for data scientist is the Seaborn \
# REF: https://seaborn.pydata.org/
#
# install it by `conda install seaborn -c conda-forge`
#
# Check [here](https://seaborn.pydata.org/examples/index.html) for more examples
